# %% [markdown]
# <a href="https://colab.research.google.com/github/mtrefilek/cs762/blob/main/Feature_Extractor_(ScatterNet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
from kymatio.torch import Scattering2D
cwd = os.getcwd().replace('\\','/')

# %%
import numpy as np
import pickle
from copy import deepcopy

# %%
SHAPES = {
    "CIFAR10": (32, 32, 3),
    "FMNIST": (28, 28, 1),
    "MNIST": (28, 28, 1)
}
n_batch = 128

# %%
def get_scatter_transform(dataset):
    shape = SHAPES[dataset]
    scattering = Scattering2D(J=2, shape=shape[:2])
    K = 81 * shape[2]
    (h, w) = shape[:2]
    return scattering, K, (h//4, w//4)

# %%
DSET_NAME = 'MNIST' #('MNIST', 'FMNIST', 'CIFAR10', 'CIFAR100', 'PlantDisease', 'EuroSAT', 'ChestXRay') 'ISIC2018', 'TinyImageNet' are not yet implemented

# %%
FEATURE_EXTRACTOR_NAME = 'scatternet'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#device = torch.device('cpu')
model, K, (h, w) = get_scatter_transform(DSET_NAME)
d_dim = K * h * w
model.to(device)
# Out:
# Scattering2D()

# %%
### Dataset Preparation
from torchvision import datasets, transforms
from glob import glob, iglob
from PIL import Image

def batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

dset_path = cwd + '/dataset'
feature_path = cwd+'/extracted_features/'

if DSET_NAME=='MNIST': # MNIST
    trainset = datasets.MNIST(root=dset_path, train=True, download=True, transform=transforms.ToTensor())
    testset = datasets.MNIST(root=dset_path, train=False, download=True, transform=transforms.ToTensor())
    imgs_tr, imgs_tst, labels_tr, labels_tst = [], [], [], []
    for (img, label) in trainset:
        imgs_tr.append(img)
        labels_tr.append(label)
    for (img, label) in testset:
        imgs_tst.append(img)
        labels_tst.append(label)    
    classnames = [str(a) for a in range(10)]

elif DSET_NAME=='FMNIST': # Fashion-MNIST
    trainset = datasets.FashionMNIST(root=dset_path, train=True, transform=transforms.ToTensor())
    testset = datasets.FashionMNIST(root=dset_path, train=False, transform=transforms.ToTensor())
    imgs_tr, imgs_tst, labels_tr, labels_tst = [], [], [], []
    for (img, label) in trainset:
        imgs_tr.append(img)
        labels_tr.append(label)
    for (img, label) in testset:
        imgs_tst.append(img)
        labels_tst.append(label)
    classnames = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

elif DSET_NAME=='CIFAR10': # CIFAR-10
    trainset = datasets.CIFAR10(root=dset_path, train=True, download=True, transform=transforms.ToTensor())
    testtest = datasets.CIFAR10(root=dset_path, train=False, download=True, transform=transforms.ToTensor())
    imgs_tr, imgs_tst, labels_tr, labels_tst = [], [], [], []
    for (img, label) in trainset:
        imgs_tr.append(img)
        labels_tr.append(label)
    for (img, label) in testset:
        imgs_tst.append(img)
        labels_tst.append(label)
    meta = pickle.load( open(dset_path+'/cifar-10-batches-py/batches.meta','rb') )
    classnames = meta['label_names']

elif DSET_NAME=='CIFAR100': # CIFAR-100
    trainset = datasets.CIFAR100(root=dset_path, train=True, download=True, transform=transforms.ToTensor())
    testset = datasets.CIFAR100(root=dset_path, train=False, download=True, transform=transforms.ToTensor())
    imgs_tr, imgs_tst, labels_tr, labels_tst = [], [], [], []
    for (img, label) in trainset:
        imgs_tr.append(img)
        labels_tr.append(label)
    for (img, label) in testset:
        imgs_tst.append(img)
        labels_tst.append(label)
    meta = pickle.load( open(dset_path+'/cifar-100-python/meta','rb') )
    classnames = meta['fine_label_names']

if DSET_NAME in ('MNIST', 'FMNIST', 'CIFAR10', 'CIFAR100'):
    n_tr = len(imgs_tr)
    feature_matrix_tr = np.zeros((1,d_dim))
    for img_batch in batch(imgs_tr, n=n_batch):
        inputs = torch.stack(img_batch).to(device)
        img_features_tr = model(inputs).cpu().detach().numpy().reshape(len(img_batch),d_dim)
        feature_matrix_tr = np.concatenate((feature_matrix_tr, img_features_tr), axis=0)
        print('Extracting Training Features: {0:.2f}% done'.format(100*len(feature_matrix_tr[1:])/n_tr) )
    feature_matrix_tr = feature_matrix_tr[1:]

    n_cls = np.max(labels_tr)+1
    labels_tr = np.array(labels_tr)
    feature_matrices_tr = []
    for i in range(n_cls):
        feature_matrices_tr.append(feature_matrix_tr[labels_tr==i])

    n_tst = len(imgs_tst)
    feature_matrix_tst = np.zeros((1,d_dim))
    for img_batch in batch(imgs_tst, n=n_batch):
        inputs = torch.stack(img_batch).to(device)
        img_features_tst = model(inputs).cpu().detach().numpy().reshape(len(img_batch),d_dim)
        feature_matrix_tst = np.concatenate((feature_matrix_tst, img_features_tst), axis=0)
        print('Extracting Test Features: {0:.2f}% done'.format(100*len(feature_matrix_tst[1:])/n_tst) )
    feature_matrix_tst = feature_matrix_tst[1:]

    n_cls = np.max(labels_tst)+1
    labels_tst = np.array(labels_tst)
    feature_matrices_tst = []
    for i in range(n_cls):
        feature_matrices_tst.append(feature_matrix_tr[labels_tst==i])
    
### Save Features
if DSET_NAME in ('MNIST', 'FMNIST', 'CIFAR10', 'CIFAR100'):
    fname_tr = DSET_NAME+'_'+FEATURE_EXTRACTOR_NAME+'_train.npz'
    fname_tst = DSET_NAME+'_'+FEATURE_EXTRACTOR_NAME+'_test.npz'

    np.savez(feature_path + fname_tr, feature_matrices = feature_matrices_tr, classnames = classnames)
    np.savez(feature_path + fname_tst, feature_matrices = feature_matrices_tst, classnames = classnames)
# Out:
# Extracting Training Features: 0.21% done
# Extracting Training Features: 0.43% done
# Extracting Training Features: 0.64% done
# Extracting Training Features: 0.85% done
# Extracting Training Features: 1.07% done
# Extracting Training Features: 1.28% done
# Extracting Training Features: 1.49% done
# Extracting Training Features: 1.71% done
# Extracting Training Features: 1.92% done
# Extracting Training Features: 2.13% done
# Extracting Training Features: 2.35% done
# Extracting Training Features: 2.56% done
# Extracting Training Features: 2.77% done
# Extracting Training Features: 2.99% done
# Extracting Training Features: 3.20% done
# Extracting Training Features: 3.41% done
# Extracting Training Features: 3.63% done
# Extracting Training Features: 3.84% done
# Extracting Training Features: 4.05% done
# Extracting Training Features: 4.27% done
# Extracting Training Features: 4.48% done
# Extracting Training Features: 4.69% done
# Extracting Training Features: 4.91% done
# Extracting Training Features: 5.12% done
# Extracting Training Features: 5.33% done
# Extracting Training Features: 5.55% done
# Extracting Training Features: 5.76% done
# Extracting Training Features: 5.97% done
# Extracting Training Features: 6.19% done
# Extracting Training Features: 6.40% done
# Extracting Training Features: 6.61% done
# Extracting Training Features: 6.83% done
# Extracting Training Features: 7.04% done
# Extracting Training Features: 7.25% done
# Extracting Training Features: 7.47% done
# Extracting Training Features: 7.68% done
# Extracting Training Features: 7.89% done
# Extracting Training Features: 8.11% done
# Extracting Training Features: 8.32% done
# Extracting Training Features: 8.53% done
# Extracting Training Features: 8.75% done
# Extracting Training Features: 8.96% done
# Extracting Training Features: 9.17% done
# Extracting Training Features: 9.39% done
# Extracting Training Features: 9.60% done
# Extracting Training Features: 9.81% done
# Extracting Training Features: 10.03% done
# Extracting Training Features: 10.24% done
# Extracting Training Features: 10.45% done
# Extracting Training Features: 10.67% done
# Extracting Training Features: 10.88% done
# Extracting Training Features: 11.09% done
# Extracting Training Features: 11.31% done
# Extracting Training Features: 11.52% done
# Extracting Training Features: 11.73% done
# Extracting Training Features: 11.95% done
# Extracting Training Features: 12.16% done
# Extracting Training Features: 12.37% done
# Extracting Training Features: 12.59% done
# Extracting Training Features: 12.80% done
# Extracting Training Features: 13.01% done
# Extracting Training Features: 13.23% done
# Extracting Training Features: 13.44% done
# Extracting Training Features: 13.65% done
# Extracting Training Features: 13.87% done
# Extracting Training Features: 14.08% done
# Extracting Training Features: 14.29% done
# Extracting Training Features: 14.51% done
# Extracting Training Features: 14.72% done
# Extracting Training Features: 14.93% done
# Extracting Training Features: 15.15% done
# Extracting Training Features: 15.36% done
# Extracting Training Features: 15.57% done
# Extracting Training Features: 15.79% done
# Extracting Training Features: 16.00% done
# Extracting Training Features: 16.21% done
# Extracting Training Features: 16.43% done
# Extracting Training Features: 16.64% done
# Extracting Training Features: 16.85% done
# Extracting Training Features: 17.07% done
# Extracting Training Features: 17.28% done
# Extracting Training Features: 17.49% done
# Extracting Training Features: 17.71% done
# Extracting Training Features: 17.92% done
# Extracting Training Features: 18.13% done
# Extracting Training Features: 18.35% done
# Extracting Training Features: 18.56% done
# Extracting Training Features: 18.77% done
# Extracting Training Features: 18.99% done
# Extracting Training Features: 19.20% done
# Extracting Training Features: 19.41% done
# Extracting Training Features: 19.63% done
# Extracting Training Features: 19.84% done
# Extracting Training Features: 20.05% done
# Extracting Training Features: 20.27% done
# Extracting Training Features: 20.48% done
# Extracting Training Features: 20.69% done
# Extracting Training Features: 20.91% done
# Extracting Training Features: 21.12% done
# Extracting Training Features: 21.33% done
# Extracting Training Features: 21.55% done
# Extracting Training Features: 21.76% done
# Extracting Training Features: 21.97% done
# Extracting Training Features: 22.19% done
# Extracting Training Features: 22.40% done
# Extracting Training Features: 22.61% done
# Extracting Training Features: 22.83% done
# Extracting Training Features: 23.04% done
# Extracting Training Features: 23.25% done
# Extracting Training Features: 23.47% done
# Extracting Training Features: 23.68% done
# Extracting Training Features: 23.89% done
# Extracting Training Features: 24.11% done
# Extracting Training Features: 24.32% done
# Extracting Training Features: 24.53% done
# Extracting Training Features: 24.75% done
# Extracting Training Features: 24.96% done
# Extracting Training Features: 25.17% done
# Extracting Training Features: 25.39% done
# Extracting Training Features: 25.60% done
# Extracting Training Features: 25.81% done
# Extracting Training Features: 26.03% done
# Extracting Training Features: 26.24% done
# Extracting Training Features: 26.45% done
# Extracting Training Features: 26.67% done
# Extracting Training Features: 26.88% done
# Extracting Training Features: 27.09% done
# Extracting Training Features: 27.31% done
# Extracting Training Features: 27.52% done
# Extracting Training Features: 27.73% done
# Extracting Training Features: 27.95% done
# Extracting Training Features: 28.16% done
# Extracting Training Features: 28.37% done
# Extracting Training Features: 28.59% done
# Extracting Training Features: 28.80% done
# Extracting Training Features: 29.01% done
# Extracting Training Features: 29.23% done
# Extracting Training Features: 29.44% done
# Extracting Training Features: 29.65% done
# Extracting Training Features: 29.87% done
# Extracting Training Features: 30.08% done
# Extracting Training Features: 30.29% done
# Extracting Training Features: 30.51% done
# Extracting Training Features: 30.72% done
# Extracting Training Features: 30.93% done
# Extracting Training Features: 31.15% done
# Extracting Training Features: 31.36% done
# Extracting Training Features: 31.57% done
# Extracting Training Features: 31.79% done
# Extracting Training Features: 32.00% done
# Extracting Training Features: 32.21% done
# Extracting Training Features: 32.43% done
# Extracting Training Features: 32.64% done
# Extracting Training Features: 32.85% done
# Extracting Training Features: 33.07% done
# Extracting Training Features: 33.28% done
# Extracting Training Features: 33.49% done
# Extracting Training Features: 33.71% done
# Extracting Training Features: 33.92% done
# Extracting Training Features: 34.13% done
# Extracting Training Features: 34.35% done
# Extracting Training Features: 34.56% done
# Extracting Training Features: 34.77% done
# Extracting Training Features: 34.99% done
# Extracting Training Features: 35.20% done
# Extracting Training Features: 35.41% done
# Extracting Training Features: 35.63% done
# Extracting Training Features: 35.84% done
# Extracting Training Features: 36.05% done
# Extracting Training Features: 36.27% done
# Extracting Training Features: 36.48% done
# Extracting Training Features: 36.69% done
# Extracting Training Features: 36.91% done
# Extracting Training Features: 37.12% done
# Extracting Training Features: 37.33% done
# Extracting Training Features: 37.55% done
# Extracting Training Features: 37.76% done
# Extracting Training Features: 37.97% done
# Extracting Training Features: 38.19% done
# Extracting Training Features: 38.40% done
# Extracting Training Features: 38.61% done
# Extracting Training Features: 38.83% done
# Extracting Training Features: 39.04% done
# Extracting Training Features: 39.25% done
# Extracting Training Features: 39.47% done
# Extracting Training Features: 39.68% done
# Extracting Training Features: 39.89% done
# Extracting Training Features: 40.11% done
# Extracting Training Features: 40.32% done
# Extracting Training Features: 40.53% done
# Extracting Training Features: 40.75% done
# Extracting Training Features: 40.96% done
# Extracting Training Features: 41.17% done
# Extracting Training Features: 41.39% done
# Extracting Training Features: 41.60% done
# Extracting Training Features: 41.81% done
# Extracting Training Features: 42.03% done
# Extracting Training Features: 42.24% done
# Extracting Training Features: 42.45% done
# Extracting Training Features: 42.67% done
# Extracting Training Features: 42.88% done
# Extracting Training Features: 43.09% done
# Extracting Training Features: 43.31% done
# Extracting Training Features: 43.52% done
# Extracting Training Features: 43.73% done
# Extracting Training Features: 43.95% done
# Extracting Training Features: 44.16% done
# Extracting Training Features: 44.37% done
# Extracting Training Features: 44.59% done
# Extracting Training Features: 44.80% done
# Extracting Training Features: 45.01% done
# Extracting Training Features: 45.23% done
# Extracting Training Features: 45.44% done
# Extracting Training Features: 45.65% done
# Extracting Training Features: 45.87% done
# Extracting Training Features: 46.08% done
# Extracting Training Features: 46.29% done
# Extracting Training Features: 46.51% done
# Extracting Training Features: 46.72% done
# Extracting Training Features: 46.93% done
# Extracting Training Features: 47.15% done
# Extracting Training Features: 47.36% done
# Extracting Training Features: 47.57% done
# Extracting Training Features: 47.79% done
# Extracting Training Features: 48.00% done
# Extracting Training Features: 48.21% done
# Extracting Training Features: 48.43% done
# Extracting Training Features: 48.64% done
# Extracting Training Features: 48.85% done
# Extracting Training Features: 49.07% done
# Extracting Training Features: 49.28% done
# Extracting Training Features: 49.49% done
# Extracting Training Features: 49.71% done
# Extracting Training Features: 49.92% done
# Extracting Training Features: 50.13% done
# Extracting Training Features: 50.35% done
# Extracting Training Features: 50.56% done
# Extracting Training Features: 50.77% done
# Extracting Training Features: 50.99% done
# Extracting Training Features: 51.20% done
# Extracting Training Features: 51.41% done
# Extracting Training Features: 51.63% done
# Extracting Training Features: 51.84% done
# Extracting Training Features: 52.05% done
# Extracting Training Features: 52.27% done
# Extracting Training Features: 52.48% done
# Extracting Training Features: 52.69% done
# Extracting Training Features: 52.91% done
# Extracting Training Features: 53.12% done
# Extracting Training Features: 53.33% done
# Extracting Training Features: 53.55% done
# Extracting Training Features: 53.76% done
# Extracting Training Features: 53.97% done
# Extracting Training Features: 54.19% done
# Extracting Training Features: 54.40% done
# Extracting Training Features: 54.61% done
# Extracting Training Features: 54.83% done
# Extracting Training Features: 55.04% done
# Extracting Training Features: 55.25% done
# Extracting Training Features: 55.47% done
# Extracting Training Features: 55.68% done
# Extracting Training Features: 55.89% done
# Extracting Training Features: 56.11% done
# Extracting Training Features: 56.32% done
# Extracting Training Features: 56.53% done
# Extracting Training Features: 56.75% done
# Extracting Training Features: 56.96% done
# Extracting Training Features: 57.17% done
# Extracting Training Features: 57.39% done
# Extracting Training Features: 57.60% done
# Extracting Training Features: 57.81% done
# Extracting Training Features: 58.03% done
# Extracting Training Features: 58.24% done
# Extracting Training Features: 58.45% done
# Extracting Training Features: 58.67% done
# Extracting Training Features: 58.88% done
# Extracting Training Features: 59.09% done
# Extracting Training Features: 59.31% done
# Extracting Training Features: 59.52% done
# Extracting Training Features: 59.73% done
# Extracting Training Features: 59.95% done
# Extracting Training Features: 60.16% done
# Extracting Training Features: 60.37% done
# Extracting Training Features: 60.59% done
# Extracting Training Features: 60.80% done
# Extracting Training Features: 61.01% done
# Extracting Training Features: 61.23% done
# Extracting Training Features: 61.44% done
# Extracting Training Features: 61.65% done
# Extracting Training Features: 61.87% done
# Extracting Training Features: 62.08% done
# Extracting Training Features: 62.29% done
# Extracting Training Features: 62.51% done
# Extracting Training Features: 62.72% done
# Extracting Training Features: 62.93% done
# Extracting Training Features: 63.15% done
# Extracting Training Features: 63.36% done
# Extracting Training Features: 63.57% done
# Extracting Training Features: 63.79% done
# Extracting Training Features: 64.00% done
# Extracting Training Features: 64.21% done
# Extracting Training Features: 64.43% done
# Extracting Training Features: 64.64% done
# Extracting Training Features: 64.85% done
# Extracting Training Features: 65.07% done
# Extracting Training Features: 65.28% done
# Extracting Training Features: 65.49% done
# Extracting Training Features: 65.71% done
# Extracting Training Features: 65.92% done
# Extracting Training Features: 66.13% done
# Extracting Training Features: 66.35% done
# Extracting Training Features: 66.56% done
# Extracting Training Features: 66.77% done
# Extracting Training Features: 66.99% done
# Extracting Training Features: 67.20% done
# Extracting Training Features: 67.41% done
# Extracting Training Features: 67.63% done
# Extracting Training Features: 67.84% done
# Extracting Training Features: 68.05% done
# Extracting Training Features: 68.27% done
# Extracting Training Features: 68.48% done
# Extracting Training Features: 68.69% done
# Extracting Training Features: 68.91% done
# Extracting Training Features: 69.12% done
# Extracting Training Features: 69.33% done
# Extracting Training Features: 69.55% done
# Extracting Training Features: 69.76% done
# Extracting Training Features: 69.97% done
# Extracting Training Features: 70.19% done
# Extracting Training Features: 70.40% done
# Extracting Training Features: 70.61% done
# Extracting Training Features: 70.83% done
# Extracting Training Features: 71.04% done
# Extracting Training Features: 71.25% done
# Extracting Training Features: 71.47% done
# Extracting Training Features: 71.68% done
# Extracting Training Features: 71.89% done
# Extracting Training Features: 72.11% done
# Extracting Training Features: 72.32% done
# Extracting Training Features: 72.53% done
# Extracting Training Features: 72.75% done
# Extracting Training Features: 72.96% done
# Extracting Training Features: 73.17% done
# Extracting Training Features: 73.39% done
# Extracting Training Features: 73.60% done
# Extracting Training Features: 73.81% done
# Extracting Training Features: 74.03% done
# Extracting Training Features: 74.24% done
# Extracting Training Features: 74.45% done
# Extracting Training Features: 74.67% done
# Extracting Training Features: 74.88% done
# Extracting Training Features: 75.09% done
# Extracting Training Features: 75.31% done
# Extracting Training Features: 75.52% done
# Extracting Training Features: 75.73% done
# Extracting Training Features: 75.95% done
# Extracting Training Features: 76.16% done
# Extracting Training Features: 76.37% done
# Extracting Training Features: 76.59% done
# Extracting Training Features: 76.80% done
# Extracting Training Features: 77.01% done
# Extracting Training Features: 77.23% done
# Extracting Training Features: 77.44% done
# Extracting Training Features: 77.65% done
# Extracting Training Features: 77.87% done
# Extracting Training Features: 78.08% done
# Extracting Training Features: 78.29% done
# Extracting Training Features: 78.51% done
# Extracting Training Features: 78.72% done
# Extracting Training Features: 78.93% done
# Extracting Training Features: 79.15% done
# Extracting Training Features: 79.36% done
# Extracting Training Features: 79.57% done
# Extracting Training Features: 79.79% done
# Extracting Training Features: 80.00% done
# Extracting Training Features: 80.21% done
# Extracting Training Features: 80.43% done
# Extracting Training Features: 80.64% done
# Extracting Training Features: 80.85% done
# Extracting Training Features: 81.07% done
# Extracting Training Features: 81.28% done
# Extracting Training Features: 81.49% done
# Extracting Training Features: 81.71% done
# Extracting Training Features: 81.92% done
# Extracting Training Features: 82.13% done
# Extracting Training Features: 82.35% done
# Extracting Training Features: 82.56% done
# Extracting Training Features: 82.77% done
# Extracting Training Features: 82.99% done
# Extracting Training Features: 83.20% done
# Extracting Training Features: 83.41% done
# Extracting Training Features: 83.63% done
# Extracting Training Features: 83.84% done
# Extracting Training Features: 84.05% done
# Extracting Training Features: 84.27% done
# Extracting Training Features: 84.48% done
# Extracting Training Features: 84.69% done
# Extracting Training Features: 84.91% done
# Extracting Training Features: 85.12% done
# Extracting Training Features: 85.33% done
# Extracting Training Features: 85.55% done
# Extracting Training Features: 85.76% done
# Extracting Training Features: 85.97% done
# Extracting Training Features: 86.19% done
# Extracting Training Features: 86.40% done
# Extracting Training Features: 86.61% done
# Extracting Training Features: 86.83% done
# Extracting Training Features: 87.04% done
# Extracting Training Features: 87.25% done
# Extracting Training Features: 87.47% done
# Extracting Training Features: 87.68% done
# Extracting Training Features: 87.89% done
# Extracting Training Features: 88.11% done
# Extracting Training Features: 88.32% done
# Extracting Training Features: 88.53% done
# Extracting Training Features: 88.75% done
# Extracting Training Features: 88.96% done
# Extracting Training Features: 89.17% done
# Extracting Training Features: 89.39% done
# Extracting Training Features: 89.60% done
# Extracting Training Features: 89.81% done
# Extracting Training Features: 90.03% done
# Extracting Training Features: 90.24% done
# Extracting Training Features: 90.45% done
# Extracting Training Features: 90.67% done
# Extracting Training Features: 90.88% done
# Extracting Training Features: 91.09% done
# Extracting Training Features: 91.31% done
# Extracting Training Features: 91.52% done
# Extracting Training Features: 91.73% done
# Extracting Training Features: 91.95% done
# Extracting Training Features: 92.16% done
# Extracting Training Features: 92.37% done
# Extracting Training Features: 92.59% done
# Extracting Training Features: 92.80% done
# Extracting Training Features: 93.01% done
# Extracting Training Features: 93.23% done
# Extracting Training Features: 93.44% done
# Extracting Training Features: 93.65% done
# Extracting Training Features: 93.87% done
# Extracting Training Features: 94.08% done
# Extracting Training Features: 94.29% done
# Extracting Training Features: 94.51% done
# Extracting Training Features: 94.72% done
# Extracting Training Features: 94.93% done
# Extracting Training Features: 95.15% done
# Extracting Training Features: 95.36% done
# Extracting Training Features: 95.57% done
# Extracting Training Features: 95.79% done
# Extracting Training Features: 96.00% done
# Extracting Training Features: 96.21% done
# Extracting Training Features: 96.43% done
# Extracting Training Features: 96.64% done
# Extracting Training Features: 96.85% done
# Extracting Training Features: 97.07% done
# Extracting Training Features: 97.28% done
# Extracting Training Features: 97.49% done
# Extracting Training Features: 97.71% done
# Extracting Training Features: 97.92% done
# Extracting Training Features: 98.13% done
# Extracting Training Features: 98.35% done
# Extracting Training Features: 98.56% done
# Extracting Training Features: 98.77% done
# Extracting Training Features: 98.99% done
# Extracting Training Features: 99.20% done
# Extracting Training Features: 99.41% done
# Extracting Training Features: 99.63% done
# Extracting Training Features: 99.84% done
# Extracting Training Features: 100.00% done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-232b8dc3accb> in <module>
#      76     feature_matrices_tr = []
#      77     for i in range(n_cls):
# ---> 78         feature_matrices_tr.append(feature_matrix[labels_tr==i])
#      79
#      80     n_tst = len(imgs_tst)
#
# NameError: name 'feature_matrix' is not defined

# %%
n_cls = np.max(labels_tr)+1
labels_tr = np.array(labels_tr)
feature_matrices_tr = []
for i in range(n_cls):
    feature_matrices_tr.append(feature_matrix_tr[labels_tr==i])

# %%
len(feature_matrices_tr)
# Out:
# 10

# %%
np.sum([len(f) for f in feature_matrices_tr])
# Out:
# 60000

# %%
len(labels_tr==i)
# Out:
# 60000

# %%
len(labels_tr)
# Out:
# 60000

# %%
i
# Out:
# 9
